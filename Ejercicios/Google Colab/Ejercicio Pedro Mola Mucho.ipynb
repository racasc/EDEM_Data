# %%
data=json.loads("""{
   "id": 0,
  "category": {
    "id": 0,
    "name": "Scooby-Doo"
  },
  "name": "doggie",
  "photoUrls": [
    "https://hips.hearstapps.com/es.h-cdn.co/fotoes/images/noticias/vuelve-scooby-doo/7871382-1-esl-ES/Vuelve-Scooby-Doo.jpg"
  ],
  "tags": [
    {
      "id": 0,
      "name": "animado"
    }
  ],
  "status": "available"
}""")

response =  requests.post (urls="https://petstore.swagger.io/v2/pet/" )
